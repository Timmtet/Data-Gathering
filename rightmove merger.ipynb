# %%
import os
import glob
import pandas as pd

# Set the directory where your CSV files are located
csv_dir = "C:\\Users\\user\\Downloads\\Timmtet\\Projects\\WKcoding"

# Get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_dir, '*.csv'))

# Initialize an empty list to store the dataframes
dfs = []

# Loop through the CSV files and read them in as dataframes
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

# Concatenate all of the dataframes together
merged_df = pd.concat(dfs, ignore_index=True)

# Print the merged dataframe
print(merged_df)
# Out:
#        Unnamed: 0   Unique_Id Location Tansaction_Type  Property_Type
# 0             0.0  DA17S00001     DA17           Sales       Detached  \
# 1             1.0  DA17S00002     DA17           Sales       Detached
# 2             2.0  DA17S00003     DA17           Sales  Semi-Detached
# 3             3.0  DA17S00004     DA17           Sales       Bungalow
# 4             4.0  DA17S00005     DA17           Sales  Semi-Detached
# ...           ...         ...      ...             ...            ...
# 44493      8472.0  WC2RS00047     WC2R           Sales           Flat
# 44494      8473.0  WC2RS00048     WC2R           Sales           Flat
# 44495      8474.0  WC2RS00049     WC2R           Sales      Apartment
# 44496      8475.0  WC2RS00050     WC2R           Sales      Apartment
# 44497      8476.0  WC2RS00051     WC2R           Sales    Ground Flat
#
#                                                  Address  Bedrooms  Bathrooms
# ...

# %%
merged_df.shape
# Out:
# (44498, 15)

# %%
merged_df = merged_df.drop('Unnamed: 0', axis=1)

# %%
pd.options.display.max_columns = None
merged_df = merged_df.drop('H', axis=1)
merged_df
# Out:
#         Unique_Id Location Tansaction_Type  Property_Type
# 0      DA17S00001     DA17           Sales       Detached  \
# 1      DA17S00002     DA17           Sales       Detached
# 2      DA17S00003     DA17           Sales  Semi-Detached
# 3      DA17S00004     DA17           Sales       Bungalow
# 4      DA17S00005     DA17           Sales  Semi-Detached
# ...           ...      ...             ...            ...
# 44493  WC2RS00047     WC2R           Sales           Flat
# 44494  WC2RS00048     WC2R           Sales           Flat
# 44495  WC2RS00049     WC2R           Sales      Apartment
# 44496  WC2RS00050     WC2R           Sales      Apartment
# 44497  WC2RS00051     WC2R           Sales    Ground Flat
#
#                                                  Address  Bedrooms  Bathrooms
# 0                          Bedwell Road, Belvedere, DA17         3          1  \
# 1                     Grant Close, Upper Belvedere, DA17         4          2
# ...

# %%
merged_df.to_csv('RightMove_Sales_data2.csv')

# %%
df3 = pd.read_csv('RightMove_Sales00.csv')

# %%
df3
# Out:
#       Unnamed: 0   Unique_Id Location Tansaction_Type        Property_Type
# 0              0   BR1S00001      BR1           Sales             Terraced  \
# 1              1   BR1S00002      BR1           Sales             Detached
# 2              2   BR1S00003      BR1           Sales             Detached
# 3              3   BR1S00004      BR1           Sales             Detached
# 4              4   BR1S00005      BR1           Sales                House
# ...          ...         ...      ...             ...                  ...
# 5138        5138  DA16S00138     DA16           Sales  Retirement Property
# 5139        5139  DA16S00139     DA16           Sales                 Flat
# 5140        5140  DA16S00140     DA16           Sales  Retirement Property
# 5141        5141  DA16S00141     DA16           Sales            Apartment
# 5142        5142  DA16S00142     DA16           Sales                 Flat
#
# ...

# %%
df3 = df3.drop('Unnamed: 0', axis=1)

# %%
df3.shape
# Out:
# (5143, 13)

# %%
df3
# Out:
#        Unique_Id Location Tansaction_Type        Property_Type
# 0      BR1S00001      BR1           Sales             Terraced  \
# 1      BR1S00002      BR1           Sales             Detached
# 2      BR1S00003      BR1           Sales             Detached
# 3      BR1S00004      BR1           Sales             Detached
# 4      BR1S00005      BR1           Sales                House
# ...          ...      ...             ...                  ...
# 5138  DA16S00138     DA16           Sales  Retirement Property
# 5139  DA16S00139     DA16           Sales                 Flat
# 5140  DA16S00140     DA16           Sales  Retirement Property
# 5141  DA16S00141     DA16           Sales            Apartment
# 5142  DA16S00142     DA16           Sales                 Flat
#
#                                                 Address  Bedrooms  Bathrooms
# 0                             Palace View, Bromley, BR1         3          1  \
# ...

# %%
merged = pd.concat([df3, merged_df], ignore_index=True)

# %%
merged.shape
# Out:
# (49641, 13)

# %%
merged.to_csv('RightMove_Sales_data.csv')
