# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
codes = pd.read_csv('London postcode districts.xlsx - PC DIST.csv')

# %%
def rightMove(i, Trans_type, website, df):
    s = Service("C:\\Users\\user\\Downloads\\Set ups\\chromedriver_win32\\chromedriver.exe")
    #s = Service("C:\\Users\\akint\\Downloads\\Set up files\\chromedriver.exe")
    driver = webdriver.Chrome(service= s)

    driver.get('https://www.rightmove.co.uk/')
    driver.maximize_window()
    time.sleep(2)

    time.sleep(1)
    search = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/main/div[1]/div/div/div/div/input')
    search.send_keys(postcode)

    time.sleep(2)
    driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/main/div[1]/div/div/div/button[1]').click()

    time.sleep(2)
    driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div/div[1]/div/form/fieldset[2]/div[4]/button').click()

    Trans_type = []
    address = []
    types = []
    bedrooms = []
    bathrooms = []
    prices = []
    desc = []
    date_added = []
    agent_list = []
    property_url = []
    website = []
    
    df = pd.DataFrame()
    
    i = 1
    while True:
        time.sleep(2)
        print("{} {} {} {}".format('scraping page', i,'from', postcode ))
        address_list = driver.find_elements(by='class name', value='propertyCard-address')
        type_list = driver.find_elements(By.XPATH, "//div/div/div[4]/div[1]/div[2]/a/div/span[1]")
        bedroom_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[2]/a/div/span[3]')
        bathroom_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[2]/a/div/span[5]')
        price_list = driver.find_elements(By.XPATH, '//div/div/div[3]/div/a/div[1]')
        desc_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[3]/a/span/span')
        date_added_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[2]/div/span')
        agent_list_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[2]/div')
        property_url_list = driver.current_url
        Trans_type_list = Trans_type
        website_list = website
        for address_item, type_item, bedroom_item, bathroom_item, price_item, desc_item, date_added_item, agent_list_item in zip(address_list, type_list, bedroom_list, bathroom_list, price_list, desc_list, date_added_list, agent_list_list):
            address.append(address_item.text)
            types.append(type_item.text)
            bedrooms.append(bedroom_item.text)
            bathrooms.append(bathroom_item.text)
            prices.append(price_item.text)
            desc.append(desc_item.text)
            date_added.append(date_added_item.text)
            agent_list.append(agent_list_item.text)
            property_url.append(property_url_list)
            Trans_type.append(Trans_type_list)
            website.append(website_list)
        next_botton = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div[1]/div[3]/div/div/div/div[3]/button/span')
        last_botton_check = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div[1]/div[3]/div/div/div/div[3]/button')
        html = last_botton_check.get_attribute('outerHTML') 
        if 'disabled' in html:
            print('------------------------------- SCRAPING COMPLETED FOR ' + postcode)
            break
        next_botton.click()
        i += 1
        time.sleep(2)
        
    df1 = pd.DataFrame({'Location': postcode, 'Tansaction_Type': 'Sales','Property_Type':types, 'Address' :address, 'Bedrooms': bedrooms, 'Bathrooms':bathrooms, 'Price':prices, 'Description': desc, 'Listing_Date':date_added, 'Agent':agent_list, 'Listing_Source': 'RightMove', 'listing_URL':property_url})
    df1.insert(0, 'Unique_Id', [f'{postcode}S{i+1:05d}' for i in range(len(df1))])
    print('Total numbers of properties available in ' + postcode + ' is ' + str(df1.shape[0]))

    
    df = pd.concat([df, df1], ignore_index=True)
    return df1

# %%
# create an empty DataFrame outside the function
df = pd.DataFrame()

# loop through postcodes
for postcode in codes.loc[188:]['Postcode district']:
    # call the function and pass the empty DataFrame as an argument
    df1 = rightMove(postcode, 'Sales', 'RightMove', df)
    # append the df1 DataFrame to the empty DataFrame
    df = pd.concat([df, df1], ignore_index=True)
print('------------------------ WEB SCRAPING COMPLETED: OVERALL TOTAL NUMBER OF PROPERTIES SCRAPED IS ' + str(df.shape[0]))
# Out:
# scraping page 1 from SW1V
# scraping page 2 from SW1V
# scraping page 3 from SW1V
# scraping page 4 from SW1V
# scraping page 5 from SW1V
# scraping page 6 from SW1V
# scraping page 7 from SW1V
# scraping page 8 from SW1V
# scraping page 9 from SW1V
# scraping page 10 from SW1V
# scraping page 11 from SW1V
# scraping page 12 from SW1V
# scraping page 13 from SW1V
# scraping page 14 from SW1V
# ------------------------------- SCRAPING COMPLETED FOR SW1V
# Total numbers of properties available in SW1V is 264
# scraping page 1 from SW1W
# scraping page 2 from SW1W
# scraping page 3 from SW1W
# scraping page 4 from SW1W
# scraping page 5 from SW1W
# scraping page 6 from SW1W
# scraping page 7 from SW1W
# ------------------------------- SCRAPING COMPLETED FOR SW1W
# Total numbers of properties available in SW1W is 151
# scraping page 1 from SW1X
# scraping page 2 from SW1X
# scraping page 3 from SW1X
# scraping page 4 from SW1X
# scraping page 5 from SW1X
# scraping page 6 from SW1X
# scraping page 7 from SW1X
# scraping page 8 from SW1X
# scraping page 9 from SW1X
# scraping page 10 from SW1X
# scraping page 11 from SW1X
# scraping page 12 from SW1X
# scraping page 13 from SW1X
# scraping page 14 from SW1X
# ------------------------------- SCRAPING COMPLETED FOR SW1X
# Total numbers of properties available in SW1X is 280
# scraping page 1 from SW1Y
# ------------------------------- SCRAPING COMPLETED FOR SW1Y
# Total numbers of properties available in SW1Y is 14
# scraping page 1 from SW2
# scraping page 2 from SW2
# scraping page 3 from SW2
# scraping page 4 from SW2
# scraping page 5 from SW2
# scraping page 6 from SW2
# scraping page 7 from SW2
# scraping page 8 from SW2
# scraping page 9 from SW2
# scraping page 10 from SW2
# scraping page 11 from SW2
# scraping page 12 from SW2
# scraping page 13 from SW2
# scraping page 14 from SW2
# scraping page 15 from SW2
# scraping page 16 from SW2
# ------------------------------- SCRAPING COMPLETED FOR SW2
# Total numbers of properties available in SW2 is 354
# scraping page 1 from SW20
# scraping page 2 from SW20
# scraping page 3 from SW20
# scraping page 4 from SW20
# scraping page 5 from SW20
# scraping page 6 from SW20
# scraping page 7 from SW20
# scraping page 8 from SW20
# scraping page 9 from SW20
# scraping page 10 from SW20
# scraping page 11 from SW20
# scraping page 12 from SW20
# ------------------------------- SCRAPING COMPLETED FOR SW20
# Total numbers of properties available in SW20 is 263
# scraping page 1 from SW3
# scraping page 2 from SW3
# scraping page 3 from SW3
# scraping page 4 from SW3
# scraping page 5 from SW3
# scraping page 6 from SW3
# scraping page 7 from SW3
# scraping page 8 from SW3
# scraping page 9 from SW3
# scraping page 10 from SW3
# scraping page 11 from SW3
# scraping page 12 from SW3
# scraping page 13 from SW3
# scraping page 14 from SW3
# scraping page 15 from SW3
# scraping page 16 from SW3
# scraping page 17 from SW3
# scraping page 18 from SW3
# scraping page 19 from SW3
# scraping page 20 from SW3
# scraping page 21 from SW3
# scraping page 22 from SW3
# scraping page 23 from SW3
# ------------------------------- SCRAPING COMPLETED FOR SW3
# Total numbers of properties available in SW3 is 507
# scraping page 1 from SW4
# scraping page 2 from SW4
# scraping page 3 from SW4
# scraping page 4 from SW4
# scraping page 5 from SW4
# scraping page 6 from SW4
# scraping page 7 from SW4
# scraping page 8 from SW4
# scraping page 9 from SW4
# scraping page 10 from SW4
# scraping page 11 from SW4
# scraping page 12 from SW4
# scraping page 13 from SW4
# ------------------------------- SCRAPING COMPLETED FOR SW4
# Total numbers of properties available in SW4 is 289
# scraping page 1 from SW5
# scraping page 2 from SW5
# scraping page 3 from SW5
# scraping page 4 from SW5
# scraping page 5 from SW5
# scraping page 6 from SW5
# scraping page 7 from SW5
# scraping page 8 from SW5
# scraping page 9 from SW5
# scraping page 10 from SW5
# scraping page 11 from SW5
# scraping page 12 from SW5
# scraping page 13 from SW5
# ------------------------------- SCRAPING COMPLETED FOR SW5
# Total numbers of properties available in SW5 is 293
# scraping page 1 from SW6
# scraping page 2 from SW6
# scraping page 3 from SW6
# scraping page 4 from SW6
# scraping page 5 from SW6
# scraping page 6 from SW6
# scraping page 7 from SW6
# scraping page 8 from SW6
# scraping page 9 from SW6
# scraping page 10 from SW6
# scraping page 11 from SW6
# scraping page 12 from SW6
# scraping page 13 from SW6
# scraping page 14 from SW6
# scraping page 15 from SW6
# scraping page 16 from SW6
# scraping page 17 from SW6
# scraping page 18 from SW6
# scraping page 19 from SW6
# scraping page 20 from SW6
# scraping page 21 from SW6
# scraping page 22 from SW6
# scraping page 23 from SW6
# scraping page 24 from SW6
# scraping page 25 from SW6
# scraping page 26 from SW6
# scraping page 27 from SW6
# scraping page 28 from SW6
# scraping page 29 from SW6
# scraping page 30 from SW6
# scraping page 31 from SW6
# scraping page 32 from SW6
# scraping page 33 from SW6
# scraping page 34 from SW6
# scraping page 35 from SW6
# scraping page 36 from SW6
# scraping page 37 from SW6
# scraping page 38 from SW6
# scraping page 39 from SW6
# scraping page 40 from SW6
# scraping page 41 from SW6
# scraping page 42 from SW6
# scraping page 43 from SW6
# scraping page 44 from SW6
# scraping page 45 from SW6
# scraping page 46 from SW6
# ------------------------------- SCRAPING COMPLETED FOR SW6
# Total numbers of properties available in SW6 is 927
# scraping page 1 from SW7
# scraping page 2 from SW7
# scraping page 3 from SW7
# scraping page 4 from SW7
# scraping page 5 from SW7
# scraping page 6 from SW7
# scraping page 7 from SW7
# scraping page 8 from SW7
# scraping page 9 from SW7
# scraping page 10 from SW7
# scraping page 11 from SW7
# scraping page 12 from SW7
# scraping page 13 from SW7
# scraping page 14 from SW7
# scraping page 15 from SW7
# scraping page 16 from SW7
# scraping page 17 from SW7
# scraping page 18 from SW7
# scraping page 19 from SW7
# scraping page 20 from SW7
# scraping page 21 from SW7
# scraping page 22 from SW7
# scraping page 23 from SW7
# ------------------------------- SCRAPING COMPLETED FOR SW7
# Total numbers of properties available in SW7 is 498
# scraping page 1 from SW8
# scraping page 2 from SW8
# scraping page 3 from SW8
# scraping page 4 from SW8
# scraping page 5 from SW8
# scraping page 6 from SW8
# scraping page 7 from SW8
# scraping page 8 from SW8
# scraping page 9 from SW8
# scraping page 10 from SW8
# scraping page 11 from SW8
# scraping page 12 from SW8
# scraping page 13 from SW8
# scraping page 14 from SW8
# scraping page 15 from SW8
# scraping page 16 from SW8
# scraping page 17 from SW8
# scraping page 18 from SW8
# scraping page 19 from SW8
# scraping page 20 from SW8
# scraping page 21 from SW8
# scraping page 22 from SW8
# scraping page 23 from SW8
# scraping page 24 from SW8
# scraping page 25 from SW8
# scraping page 26 from SW8
# scraping page 27 from SW8
# scraping page 28 from SW8
# scraping page 29 from SW8
# scraping page 30 from SW8
# scraping page 31 from SW8
# scraping page 32 from SW8
# scraping page 33 from SW8
# scraping page 34 from SW8
# scraping page 35 from SW8
# scraping page 36 from SW8
# scraping page 37 from SW8
# ------------------------------- SCRAPING COMPLETED FOR SW8
# Total numbers of properties available in SW8 is 742
# scraping page 1 from SW9
# scraping page 2 from SW9
# scraping page 3 from SW9
# scraping page 4 from SW9
# scraping page 5 from SW9
# scraping page 6 from SW9
# scraping page 7 from SW9
# scraping page 8 from SW9
# scraping page 9 from SW9
# scraping page 10 from SW9
# ------------------------------- SCRAPING COMPLETED FOR SW9
# Total numbers of properties available in SW9 is 190
# scraping page 1 from TN14
# scraping page 2 from TN14
# scraping page 3 from TN14
# scraping page 4 from TN14
# scraping page 5 from TN14
# ------------------------------- SCRAPING COMPLETED FOR TN14
# Total numbers of properties available in TN14 is 105
# scraping page 1 from TN16
# scraping page 2 from TN16
# scraping page 3 from TN16
# scraping page 4 from TN16
# scraping page 5 from TN16
# scraping page 6 from TN16
# scraping page 7 from TN16
# scraping page 8 from TN16
# ------------------------------- SCRAPING COMPLETED FOR TN16
# Total numbers of properties available in TN16 is 159
# scraping page 1 from TW1
# scraping page 2 from TW1
# scraping page 3 from TW1
# scraping page 4 from TW1
# scraping page 5 from TW1
# scraping page 6 from TW1
# scraping page 7 from TW1
# scraping page 8 from TW1
# scraping page 9 from TW1
# scraping page 10 from TW1
# scraping page 11 from TW1
# scraping page 12 from TW1
# ------------------------------- SCRAPING COMPLETED FOR TW1
# Total numbers of properties available in TW1 is 270
# scraping page 1 from TW10
# scraping page 2 from TW10
# scraping page 3 from TW10
# scraping page 4 from TW10
# scraping page 5 from TW10
# scraping page 6 from TW10
# scraping page 7 from TW10
# ------------------------------- SCRAPING COMPLETED FOR TW10
# Total numbers of properties available in TW10 is 159
# scraping page 1 from TW11
# scraping page 2 from TW11
# scraping page 3 from TW11
# scraping page 4 from TW11
# scraping page 5 from TW11
# scraping page 6 from TW11
# scraping page 7 from TW11
# scraping page 8 from TW11
# scraping page 9 from TW11
# ------------------------------- SCRAPING COMPLETED FOR TW11
# Total numbers of properties available in TW11 is 205
# scraping page 1 from TW12
# scraping page 2 from TW12
# scraping page 3 from TW12
# scraping page 4 from TW12
# scraping page 5 from TW12
# scraping page 6 from TW12
# scraping page 7 from TW12
# scraping page 8 from TW12
# ------------------------------- SCRAPING COMPLETED FOR TW12
# Total numbers of properties available in TW12 is 164
# scraping page 1 from TW13
# scraping page 2 from TW13
# scraping page 3 from TW13
# scraping page 4 from TW13
# scraping page 5 from TW13
# scraping page 6 from TW13
# scraping page 7 from TW13
# ------------------------------- SCRAPING COMPLETED FOR TW13
# Total numbers of properties available in TW13 is 159
# scraping page 1 from TW14
# scraping page 2 from TW14
# scraping page 3 from TW14
# scraping page 4 from TW14
# scraping page 5 from TW14
# ------------------------------- SCRAPING COMPLETED FOR TW14
# Total numbers of properties available in TW14 is 102
# scraping page 1 from TW16
# scraping page 2 from TW16
# scraping page 3 from TW16
# scraping page 4 from TW16
# scraping page 5 from TW16
# scraping page 6 from TW16
# scraping page 7 from TW16
# scraping page 8 from TW16
# scraping page 9 from TW16
# ------------------------------- SCRAPING COMPLETED FOR TW16
# Total numbers of properties available in TW16 is 202
# scraping page 1 from TW19
# scraping page 2 from TW19
# scraping page 3 from TW19
# scraping page 4 from TW19
# scraping page 5 from TW19
# ------------------------------- SCRAPING COMPLETED FOR TW19
# Total numbers of properties available in TW19 is 91
# scraping page 1 from TW2
# scraping page 2 from TW2
# scraping page 3 from TW2
# scraping page 4 from TW2
# scraping page 5 from TW2
# scraping page 6 from TW2
# scraping page 7 from TW2
# scraping page 8 from TW2
# scraping page 9 from TW2
# ------------------------------- SCRAPING COMPLETED FOR TW2
# Total numbers of properties available in TW2 is 211
# scraping page 1 from TW3
# scraping page 2 from TW3
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       4 # loop through postcodes
#       5 for postcode in codes.loc[188:]['Postcode district']:
#       6     # call the function and pass the empty DataFrame as an argument
# ----> 7     df1 = rightMove(postcode, 'Sales', 'RightMove', df)
#       8     # append the df1 DataFrame to the empty DataFrame
#       9     df = pd.concat([df, df1], ignore_index=True)
#
# Input In [8], in rightMove(i, Trans_type, website, df)
#      49 for address_item, type_item, bedroom_item, bathroom_item, price_item, desc_item, date_added_item, agent_list_item in zip(address_list, type_list, bedroom_list, bathroom_list, price_list, desc_list, date_added_list, agent_list_list):
#      50     address.append(address_item.text)
# ---> 51     types.append(type_item.text)
#      52     bedrooms.append(bedroom_item.text)
#      53     bathrooms.append(bathroom_item.text)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=113.0.5672.64)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x004B8893+48451]
# 	(No symbol) [0x0044B8A1]
# 	(No symbol) [0x00355058]
# 	(No symbol) [0x00348205]
# 	(No symbol) [0x0034810C]
# 	(No symbol) [0x00346D46]
# 	(No symbol) [0x003475CA]
# 	(No symbol) [0x00358067]
# 	(No symbol) [0x00359631]
# 	(No symbol) [0x003596D0]
# 	(No symbol) [0x0037CE4D]
# 	(No symbol) [0x0039A2BC]
# 	(No symbol) [0x00379586]
# 	(No symbol) [0x0039A614]
# 	(No symbol) [0x003AC482]
# 	(No symbol) [0x0039A0B6]
# 	(No symbol) [0x00377E08]
# 	(No symbol) [0x00378F2D]
# 	GetHandleVerifier [0x00718E3A+2540266]
# 	GetHandleVerifier [0x00758959+2801161]
# 	GetHandleVerifier [0x0075295C+2776588]
# 	GetHandleVerifier [0x00542280+612144]
# 	(No symbol) [0x00454F6C]
# 	(No symbol) [0x004511D8]
# 	(No symbol) [0x004512BB]
# 	(No symbol) [0x00444857]
# 	BaseThreadInitThunk [0x76EC0099+25]
# 	RtlGetAppContainerNamedObjectPath [0x77547B6E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77547B3E+238]

# %%
df.to_csv('RightMove_Sales4.csv')

# %%
df.tail()
# Out:
#       Unique_Id Location Tansaction_Type Property_Type  \
# 6594  TW2S00207      TW2           Sales          Flat
# 6595  TW2S00208      TW2           Sales          Flat
# 6596  TW2S00209      TW2           Sales          Flat
# 6597  TW2S00210      TW2           Sales        Studio
# 6598  TW2S00211      TW2           Sales     Apartment
#
#                               Address Bedrooms Bathrooms     Price  \
# 6594  Wellesley Road, Strawberry Hill        1         1  £325,000
# 6595         Hampton Road, Twickenham        1         1  £315,000
# 6596  Langhorn Drive, Twickenham, TW2        1         1  £315,000
# 6597         Hampton Road, Twickenham        1         1  £299,950
# 6598  Langhorn Drive, Twickenham, TW2        1         1  £270,000
#
#                                             Description  \
# 6594  Offered with no onward chain, this spacious, b...
# 6595  Offers over £315,000. Situated in a sought aft...
# 6596  A fantastic opportunity to purchase this immac...
# 6597  Offered with no onward chain is this impressiv...
# 6598  Being Sold via Secure Sale online bidding. Ter...
#
#                Listing_Date  \
# 6594  Reduced on 04/10/2022
# 6595    Added on 22/03/2023
# 6596  Reduced on 03/05/2023
# 6597  Reduced on 20/02/2023
# 6598    Added on 14/04/2023
#
#                                                   Agent Listing_Source  \
# 6594         Added on 02/03/2023 by Dexters, Twickenham      RightMove
# 6595  Reduced on 04/10/2022 by Stirling Ackroyd, Twi...      RightMove
# 6596         Added on 22/03/2023 by Dexters, Twickenham      RightMove
# 6597       Reduced on 03/05/2023 by Dexters, Twickenham      RightMove
# 6598  Reduced on 20/02/2023 by Purplebricks, coverin...      RightMove
#
#                                             listing_URL
# 6594  https://www.rightmove.co.uk/property-for-sale/...
# 6595  https://www.rightmove.co.uk/property-for-sale/...
# 6596  https://www.rightmove.co.uk/property-for-sale/...
# 6597  https://www.rightmove.co.uk/property-for-sale/...
# 6598  https://www.rightmove.co.uk/property-for-sale/...

# %%
codes.loc[188:]
# Out:
#     Postcode district                                        Local Areas  \
# 188              SW1V  Vauxhall Bridge, Chelsea Bridge, Victoria Stat...
# 189              SW1W                                          Belgravia
# 190              SW1X                           Belgravia, Knightsbridge
# 191              SW1Y                                        St. James's
# 192               SW2  Brixton, Brixton Hill, Streatham Hill, Tulse H...
# ..                ...                                                ...
# 263              WC2B                                Drury Lane, Aldwych
# 264              WC2E                                      Covent Garden
# 265              WC2H                                   Leicester Square
# 266              WC2N                                      Charing Cross
# 267              WC2R                                     Somerset House
#
#          Borough
# 188  Westminster
# 189  Westminster
# 190  Westminster
# 191  Westminster
# 192      Lambeth
# ..           ...
# 263       Camden
# 264  Westminster
# 265  Westminster
# 266  Westminster
# 267  Westminster
#
# [80 rows x 3 columns]

# %%
df.tail()
# Out:
#       Unique_Id Location Tansaction_Type  Property_Type  \
# 5312  DA5S00098      DA5           Sales  Semi-Detached
# 5313  DA5S00099      DA5           Sales           Flat
# 5314  DA5S00100      DA5           Sales           Flat
# 5315  DA5S00101      DA5           Sales           Flat
# 5316  DA5S00102      DA5           Sales           Flat
#
#                             Address Bedrooms Bathrooms     Price  \
# 5312              The Drive, Bexley        4         3  £750,000
# 5313  Bexley High Street Bexley DA5        2         1  £275,000
# 5314      Beaconsfield Road, Bexley        2         2  £254,950
# 5315      Beaconsfield Road, Bexley        2         2  £250,000
# 5316         Clarendon Mews, Bexley        2         1  £210,000
#
#                                             Description  \
# 5312  PRICE RANGE £750,000-£775,000. Village Estates...
# 5313  The Acorn Group are delighted to welcome to th...
# 5314  Hunters are now in receipt of an offer for the...
# 5315  ** OVER 100 YEAR LEASE ** Offered to the marke...
# 5316  GUIDE PRICE £210,000 - £220,000. Village Estat...
#
#                Listing_Date                                        Agent  \
# 5312            Added today                            Allow all cookies
# 5313  Reduced on 02/05/2023       Added today by Village Estates, Bexley
# 5314    Added on 17/02/2023     Reduced on 02/05/2023 by Acorn, Blackfen
# 5315    Added on 17/02/2023  Added on 17/02/2023 by Hunters, Bexleyheath
# 5316    Added on 03/04/2023  Added on 17/02/2023 by Hunters, Bexleyheath
#
#      Listing_Source                                        listing_URL
# 5312      RightMove  https://www.rightmove.co.uk/property-for-sale/...
# 5313      RightMove  https://www.rightmove.co.uk/property-for-sale/...
# 5314      RightMove  https://www.rightmove.co.uk/property-for-sale/...
# 5315      RightMove  https://www.rightmove.co.uk/property-for-sale/...
# 5316      RightMove  https://www.rightmove.co.uk/property-for-sale/...

# %%
def rightMove(i, Trans_type, website, df):
    s = Service("C:\\Users\\user\\Downloads\\Set ups\\chromedriver_win32\\chromedriver.exe")
    #s = Service("C:\\Users\\akint\\Downloads\\Set up files\\chromedriver.exe")
    driver = webdriver.Chrome(service= s)

    driver.get('https://www.rightmove.co.uk/')
    driver.maximize_window()
    time.sleep(2)

    time.sleep(1)
    search = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/main/div[1]/div/div/div/div/input')
    search.send_keys(postcode)

    time.sleep(2)
    driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/main/div[1]/div/div/div/button[2]').click()

    time.sleep(2)
    driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div/div[1]/div/form/fieldset[2]/div[4]/button').click()

    Trans_type = []
    address = []
    types = []
    bedrooms = []
    bathrooms = []
    prices = []
    desc = []
    date_added = []
    agent_list = []
    property_url = []
    website = []
    
    df = pd.DataFrame()
    
    i = 1
    while True:
        time.sleep(2)
        print("{} {} {} {}".format('scraping page', i,'from', postcode ))
        address_list = driver.find_elements(by='class name', value='propertyCard-address')
        type_list = driver.find_elements(By.XPATH, "//div/div/div[4]/div[1]/div[2]/a/div/span[1]")
        bedroom_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[2]/a/div/span[3]')
        bathroom_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[2]/a/div/span[5]')
        price_list = driver.find_elements(By.XPATH, '//div/div/div[3]/div/div/a/div/span[1]')
        desc_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[1]/div[3]/a/span/span')
        date_added_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[2]/div/span')
        agent_list_list = driver.find_elements(By.XPATH, '//div/div/div[4]/div[2]/div')
        property_url_list = driver.current_url
        Trans_type_list = Trans_type
        website_list = website
        for address_item, type_item, bedroom_item, bathroom_item, price_item, desc_item, date_added_item, agent_list_item in zip(address_list, type_list, bedroom_list, bathroom_list, price_list, desc_list, date_added_list, agent_list_list):
            address.append(address_item.text)
            types.append(type_item.text)
            bedrooms.append(bedroom_item.text)
            bathrooms.append(bathroom_item.text)
            prices.append(price_item.text)
            desc.append(desc_item.text)
            date_added.append(date_added_item.text)
            agent_list.append(agent_list_item.text)
            property_url.append(property_url_list)
            Trans_type.append(Trans_type_list)
            website.append(website_list)
        next_botton = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div[1]/div[3]/div/div/div/div[3]/button/span')
        last_botton_check = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div[1]/div[3]/div/div/div/div[3]/button')
        html = last_botton_check.get_attribute('outerHTML') 
        if 'disabled' in html:
            print('------------------------------- SCRAPING COMPLETED FOR ' + postcode)
            break
        next_botton.click()
        i += 1
        time.sleep(2)
        
    df1 = pd.DataFrame({'Location': postcode, 'Tansaction_Type': 'Rent','Property_Type':types, 'Address' :address, 'Bedrooms': bedrooms, 'Bathrooms':bathrooms, 'Price':prices, 'Description': desc, 'Listing_Date':date_added, 'Agent':agent_list, 'Listing_Source': 'RightMove', 'listing_URL':property_url})
    df1.insert(0, 'Unique_Id', [f'{postcode}R{i+1:05d}' for i in range(len(df1))])
    print(df1.shape)
    
    df = pd.concat([df, df1], ignore_index=True)
    return df1

# %%
# create an empty DataFrame outside the function
df = pd.DataFrame()

# loop through postcodes
for postcode in codes['Postcode district']:
    # call the function and pass the empty DataFrame as an argument
    df1 = rightMove(postcode, 'Rent', 'RightMove', df)
    # append the df1 DataFrame to the empty DataFrame
    df = pd.concat([df, df1], ignore_index=True)
print('-------------------------------    ------------------------------- WEB SCRAPING COMPLETED')
# Out:
# scraping page 1 from BR1
# scraping page 2 from BR1
# scraping page 3 from BR1
# ------------------------------- SCRAPING COMPLETED FOR BR1
# (54, 13)
# scraping page 1 from BR2
# scraping page 2 from BR2
# ------------------------------- SCRAPING COMPLETED FOR BR2
# (29, 13)
# KeyboardInterrupt

# %%
df.shape
# Out:
# (44, 13)

# %%
df
# Out:
#     Unique_Id Location Tansaction_Type  Property_Type  \
# 0   WC2N00001     WC2N            Rent     Maisonette
# 1   WC2N00002     WC2N            Rent           Flat
# 2   WC2N00003     WC2N            Rent           Flat
# 3   WC2N00004     WC2N            Rent           Flat
# 4   WC2N00005     WC2N            Rent     Maisonette
# 5   WC2N00006     WC2N            Rent           Flat
# 6   WC2N00007     WC2N            Rent           Flat
# 7   WC2N00008     WC2N            Rent       Terraced
# 8   WC2N00009     WC2N            Rent           Flat
# 9   WC2N00010     WC2N            Rent      Apartment
# 10  WC2N00011     WC2N            Rent           Flat
# 11  WC2N00012     WC2N            Rent      Apartment
# 12  WC2N00013     WC2N            Rent      Apartment
# 13  WC2N00014     WC2N            Rent           Flat
# 14  WC2N00015     WC2N            Rent      Apartment
# 15  WC2N00016     WC2N            Rent           Flat
# 16  WC2N00017     WC2N            Rent           Flat
# 17  WC2N00018     WC2N            Rent      Apartment
# 18  WC2N00019     WC2N            Rent         Duplex
# 19  WC2N00020     WC2N            Rent           Flat
# 20  WC2R00001     WC2R            Rent      Apartment
# 21  WC2R00002     WC2R            Rent         Duplex
# 22  WC2R00003     WC2R            Rent      Apartment
# 23  WC2R00004     WC2R            Rent      Apartment
# 24  WC2R00005     WC2R            Rent           Flat
# 25  WC2R00006     WC2R            Rent           Flat
# 26  WC2R00007     WC2R            Rent      Apartment
# 27  WC2R00008     WC2R            Rent      Apartment
# 28  WC2R00009     WC2R            Rent      Apartment
# 29  WC2R00010     WC2R            Rent      Apartment
# 30  WC2R00011     WC2R            Rent      Apartment
# 31  WC2R00012     WC2R            Rent           Flat
# 32  WC2R00013     WC2R            Rent           Flat
# 33  WC2R00014     WC2R            Rent      Apartment
# 34  WC2R00015     WC2R            Rent  Not Specified
# 35  WC2R00016     WC2R            Rent      Apartment
# 36  WC2R00017     WC2R            Rent           Flat
# 37  WC2R00018     WC2R            Rent      Apartment
# 38  WC2R00019     WC2R            Rent      Apartment
# 39  WC2R00020     WC2R            Rent      Apartment
# 40  WC2R00021     WC2R            Rent           Flat
# 41  WC2R00022     WC2R            Rent           Flat
# 42  WC2R00023     WC2R            Rent           Flat
# 43  WC2R00024     WC2R            Rent      Apartment
#
#                                               Address Bedrooms Bathrooms  \
# 0          Craven Street, Covent Garden, London, WC2N        3         2
# 1                Villiers Street, Covent Garden, WC2N        2         1
# 2                      John Adam Street, London, WC2N        2         1
# 3                 New Row, Covent Garden, london WC2N        1         4
# 4       St Martin's Lane, Covent Garden, London, WC2N        3         1
# 5                  Craven Street, Charing cross, WC2N        1         2
# 6                     St. Martin's Lane, London, WC2N        3         2
# 7                     St. Martin's Lane, London, WC2N        4         1
# 8                    Agar Street, Covent Garden, WC2N        2         2
# 9   Garrick House, 63-66 St Martins Lane, London, ...        2         2
# 10                     John Adam Street, London, WC2N        2         2
# 11                   Bedfordbury, Covent Garden, WC2N        2         2
# 12                         The Little Adelphi, London        2         1
# 13                           John Adam Street, Strand        2         2
# 14                     John Adam Street, London, WC2N        2         1
# 15                       John Adam Street, Bloomsbury        2         1
# 16         Craven Street, Charing cross, London, WC2N        1         2
# 17                 Craven Street, Covent Garden, WC2N        1         1
# 18              Hop House Covent Garden, London, WC2N        2         1
# 19                       New Row, Covent Garden, WC2N        1         1
# 20                 190 The Strand, Temple House, WC2R        2         2
# 21              Milford House, 190 The Strand, London        2         2
# 22       Turner House, 6 Exchange Court, London, WC2R        2         2
# 23            Temple House, 190 Strand, Covent Garden        2         2
# 24          Exchange Court, Malden Lane, London, WC2R        1         1
# 25                   Gladstone House , 190 The Strand        2         2
# 26             Temple House, 190 Strand, London, WC2R        2         2
# 27                 190 The Strand, Temple House, WC2R        2         2
# 28                                 Strand London WC2R        1         3
# 29                 190 The Strand, Temple House, WC2R        2         1
# 30                                 Strand London WC2R        3         2
# 31                      Bull Inn Court, Covent Garden        1         2
# 32                               Strand, London, WC2R        2         2
# 33                               Strand, London, WC2R        2         2
# 34                           The Strand, London, WC2R        2         1
# 35                               Strand, London, WC2R        2         1
# 36                                         215 Strand        1         3
# 37                               Strand, London, WC2R        1         1
# 38            Gladstone House, 190 Strand London WC2R        3         3
# 39                                        Strand WC2R        1         3
# 40                               Essex Street, Strand        3         3
# 41                         Essex Street, London, WC2R        3         3
# 42                                       Essex Street        3         3
# 43                 Essex Street, Temple, London, WC2R        3         2
#
#           Price                                        Description  \
# 0    £3,900 pcm  LONG LET. Set within an impressive period town...
# 1    £2,730 pcm  A well presented 2 BEDROOM APARTMENT in a rece...
# 2    £3,900 pcm  2 Double bedroom, 2 bathroom flat(1 en suite) ...
# 3    £2,500 pcm  This newly refurbished one bedroom apartment o...
# 4   £16,250 pcm  A triplex apartment of approximately 1,983 squ...
# 5    £2,383 pcm  We are proud to present this 1 bedroom first f...
# 6   £16,250 pcm  A bright and spacious 3 bedroom flat to rent i...
# 7   £16,250 pcm  A unique four bedroom Maisonette with beautifu...
# 8    £5,850 pcm  A fantastic two bedroom apartment located on t...
# 9    £4,500 pcm  A magnificent 2 bedroom Apartment in a wonderf...
# 10   £4,008 pcm  A two bedroom two bathroom property in prime c...
# 11   £5,417 pcm  Modern two bedroom apartment in Covent Garden ...
# 12   £4,008 pcm  Newly Refurbished two bedroom two bathroom apa...
# 13   £2,700 pcm  A well proportioned two double bedroom two bat...
# 14   £4,008 pcm  Tasteful two bedroom flat in the heart of the ...
# 15   £2,648 pcm  A well presented two bedroom property located ...
# 16   £1,772 pcm  Newly Decorated fully furnished bright double ...
# 17   £2,600 pcm  A modern 1 bedroom flat close to Embankment an...
# 18   £6,933 pcm  Two bedroom, Two bathroom Duplex apartment wit...
# 19   £5,633 pcm  SHORT LET - Charming 1 BEDROOM APARTMENT found...
# 20   £5,500 pcm  Regent are proud to present this luxury two-be...
# 21   £6,500 pcm  This luxurious and spacious two bedroom duplex...
# 22   £3,358 pcm  A contemporary two bedroom apartment located i...
# 23   £5,499 pcm  A premium apartment. This exceptional two bedr...
# 24   £2,600 pcm  Located in the heart of Covent Garden is this ...
# 25   £7,280 pcm  A large dual aspect 2 bedroom apartment in Gla...
# 26   £5,500 pcm  An impeccable 2 double bedroom apartment situa...
# 27   £5,300 pcm  Regent are proud to present this spectacular t...
# 28   £3,012 pcm  A stunning studio apartment in the luxurious 1...
# 29   £5,500 pcm  Regent are proud to present this luxury two-be...
# 30   £9,512 pcm  A luxurious sixth floor apartment in the moder...
# 31   £2,600 pcm  An exceptionally spacious and recently refurbi...
# 32   £6,933 pcm  This wonderful 2 bedrooms and 2 bathrooms Apar...
# 33   £7,600 pcm  A 2 double bedroom furnished apartment comes w...
# 34   £7,800 pcm  A spectacular two bedroom apartment to rent in...
# 35   £4,333 pcm  A recently refurbished property comprising two...
# 36   £2,925 pcm  This beautifully presented one bedroom flat is...
# 37   £2,925 pcm  A recently refurbished period conversion compr...
# 38   £8,450 pcm  Luxury three bedroom apartment in Gladstone Ho...
# 39   £3,445 pcm  A truly stunning studio apartment in the new 1...
# 40  £12,567 pcm  SHORT LET. An immaculate interior designed thr...
# 41  £12,567 pcm  Stunning lateral three bedroom apartment avail...
# 42  £11,265 pcm  A stunning apartment in the heart of Temple, o...
# 43  £12,567 pcm  The apartment, located on the fourth floor wit...
#
#              Listing_Date                                              Agent  \
# 0         Added yesterday                                  Allow all cookies
# 1     Added on 02/05/2023               Added yesterday by Foxtons, West End
# 2     Added on 02/05/2023  Added on 02/05/2023 by Chestertons Estate Agen...
# 3     Added on 28/04/2023  Added on 02/05/2023 by Paul Estates Ltd, Farri...
# 4     Added on 28/04/2023  Added on 28/04/2023 by Vanquish Real Estate, L...
# 5     Added on 27/04/2023  Added on 28/04/2023 by Carter Jonas Lettings, ...
# 6     Added on 26/04/2023   Added on 27/04/2023 by SN Estates London, London
# 7     Added on 26/04/2023  Added on 26/04/2023 by Knight Frank - Lettings...
# 8   Reduced on 25/04/2023  Added on 26/04/2023 by Savills Lettings, Coven...
# 9     Added on 24/04/2023  Reduced on 25/04/2023 by Draker Lettings, Sloa...
# 10    Added on 15/04/2023     Added on 24/04/2023 by Alliance London, London
# 11    Added on 13/04/2023       Added on 15/04/2023 by Harding Green, London
# 12    Added on 11/04/2023  Added on 13/04/2023 by CBRE Residential, West End
# 13    Added on 06/04/2023  Added on 11/04/2023 by Keller Williams Prime P...
# 14    Added on 31/03/2023          Added on 06/04/2023 by Dexters, Fitzrovia
# 15    Added on 31/03/2023  Added on 31/03/2023 by Russell Simpson, Chelse...
# 16    Added on 28/03/2023  Added on 31/03/2023 by Frank Harris & Co., Blo...
# 17    Added on 24/03/2023   Added on 28/03/2023 by SN Estates London, London
# 18    Added on 15/09/2022  Added on 24/03/2023 by CBRE Residential, West End
# 19    Added on 30/08/2022  Added on 15/09/2022 by Imperial Dragon Propert...
# 20  Reduced on 24/04/2023                                  Allow all cookies
# 21        Added yesterday  Reduced on 24/04/2023 by Regent Letting and Pr...
# 22        Added yesterday    Added yesterday by Prime London, Central London
# 23  Reduced on 03/05/2023  Added yesterday by Savills Lettings, Covent Ga...
# 24    Added on 02/05/2023  Reduced on 03/05/2023 by Prime London, Central...
# 25               NEW HOME          Added on 02/05/2023 by Peter Martin, NW11
# 26         ONLINE VIEWING                             NEW HOMEONLINE VIEWING
# 27  Reduced on 29/04/2023  Reduced on 29/04/2023 by Chase Apartments, London
# 28  Reduced on 27/04/2023  Reduced on 27/04/2023 by Benham & Reeves, Surr...
# 29  Reduced on 26/04/2023  Reduced on 26/04/2023 by Regent Letting and Pr...
# 30    Added on 25/04/2023  Added on 25/04/2023 by JLL, The City, Central ...
# 31  Reduced on 24/04/2023  Reduced on 24/04/2023 by Regent Letting and Pr...
# 32  Reduced on 21/04/2023  Reduced on 21/04/2023 by JLL, The City, Centra...
# 33    Added on 20/04/2023          Added on 20/04/2023 by Dexters, Fitzrovia
# 34    Added on 13/04/2023  Added on 13/04/2023 by Celestial Globe, London...
# 35    Added on 12/04/2023  Added on 12/04/2023 by Vantage Properties & Ma...
# 36    Added on 03/04/2023  Added on 03/04/2023 by CBRE Residential, West End
# 37    Added on 03/04/2023  Added on 03/04/2023 by Stirling Ackroyd Lettin...
# 38  Reduced on 03/04/2023       Reduced on 03/04/2023 by Portico, Bloomsbury
# 39    Added on 07/03/2023                                  Allow all cookies
# 40               NEW HOME     Added on 07/03/2023 by Hamptons Lettings, City
# 41  Reduced on 27/01/2023                                           NEW HOME
# 42               NEW HOME        Reduced on 27/01/2023 by Dexters, Fitzrovia
# 43    Added on 06/12/2022                                           NEW HOME
#
#    Listing_Source                                        listing_URL
# 0       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 1       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 2       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 3       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 4       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 5       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 6       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 7       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 8       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 9       RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 10      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 11      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 12      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 13      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 14      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 15      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 16      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 17      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 18      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 19      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 20      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 21      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 22      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 23      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 24      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 25      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 26      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 27      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 28      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 29      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 30      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 31      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 32      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 33      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 34      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 35      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 36      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 37      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 38      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 39      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 40      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 41      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 42      RightMove  https://www.rightmove.co.uk/property-to-rent/f...
# 43      RightMove  https://www.rightmove.co.uk/property-to-rent/f...

# %%
df.listing_URL.loc[1]
# Out:
# 'https://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier=OUTCODE%5E2800&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=on&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=&letFurnishType=&houseFlatShare='
